# %%
# %fs ls /Volumes/course_ws/default/olist

# %%
# Read CSV file dbfs: dbfs:/Volumes/course_ws/default/olist/olist_customers_dataset.csv
df = spark.read.csv("dbfs:/Volumes/course_ws/default/olist/olist_customers_dataset.csv", header=True, inferSchema=True)
display(df)

# %%
# Read delta table course_ws.default.olist_customers_dataset
df = spark.read.table("course_ws.default.olist_customers_dataset")
display(df)

# %%
df = spark.read.format.csv(abfss://dbfs-container@isiibhade.dfs.core.windows.net/landing_zone/archive/olist_geolocation_dataset.csv)
